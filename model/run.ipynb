# %%
import torch
import random
import time
import numpy as np
import pandas as pd
from torch.autograd import Variable
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import pickle
import glob
import math
import pandas as pd
import collections
import random
from torch_geometric.nn import GCNConv
from torch_geometric.data import Batch

# %% [markdown]
# ## Read demand data

# %%
def data_reader(filename):
    f = open(filename,'rb')
    data = pickle.load(f)
    return data

# %%
filename = glob.glob('../data/demand/*')
all_data = {}
node_feature = []
for i in filename:
    num = i.split('_')[1]
    data = data_reader(i)
    all_data[int(num)] = data
    node_feature.append(data)
sorted_data = collections.OrderedDict(sorted(all_data.items()))
node_feature = np.array(node_feature)

# %%
node_feature.shape
# Out:
# (262, 35064)

# %%
all_key = list(sorted_data.keys())

# %%
oldkey2newkey = {all_key[i] : i for i in range(len(all_key))}

# %% [markdown]
# ## Read graph structure¶

# %%
file = open('../data/proxList','rb')
data = pickle.load(file)

# %%
edge_index = [[], []]
for item in data:
    edge_index[0].append(item[0])
    edge_index[1].append(item[1])

# %%
initial_feature = node_feature.mean()

# %%
node_feature.mean(1).shape
# Out:
# (262,)

# %% [markdown]
# ## Clean graph

# %%
new_graph = [[], []]
for i in range(len(edge_index[0])):
    if edge_index[0][i] in all_key and edge_index[1][i] in all_key:
        new_graph[0].append(oldkey2newkey[edge_index[0][i]])
        new_graph[1].append(oldkey2newkey[edge_index[1][i]])

# %%
edge_index = torch.tensor(new_graph, dtype=torch.long)
node_feature = torch.tensor(node_feature, dtype=torch.float32)

# %% [markdown]
# ## Hyperparameters

# %%
class Args():
    def __init__(self):
        self.split_ratio = [0.7, 0.2, 0.1]
        self.hist_length = 24 
        self.pred_length = 12
        self.batch_size = 1
        self.num_node_features = 1
        self.gcn_hidden_dim = 16
        self.encoder_hidden_dim = 16
        self.decoder_hidden_dim = 16
        self.zone_num = 1
        # self.device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
        self.device = torch.device("cpu")
        self.epoch_num = 30

# %% [markdown]
# ## Dataset

# %%
class GraphDataset(Dataset):
    def __init__(self, node_feature, hist_length, pred_length):
        self.node_feature = node_feature
        self.total_len = hist_length + pred_length
        self.hist_len = hist_length
        self.pred_len = pred_length
        
    def __len__(self):
        return int(self.node_feature.shape[1] - self.total_len)
    
    def __getitem__(self, index):
        return (self.node_feature[:, index:index + self.hist_len], 
            self.node_feature[:, index + self.hist_len: index + self.total_len])

# %%
total_len = node_feature.shape[1]
train_st = 0
train_ed = math.floor(total_len * args.split_ratio[0])
valid_st = math.floor(total_len * args.split_ratio[0])
valid_ed = math.floor(total_len * (args.split_ratio[0] + args.split_ratio[1]))
test_st = math.floor(total_len * (args.split_ratio[0] + args.split_ratio[1]))
test_ed = total_len
train_dataset = GraphDataset(node_feature[:, train_st:train_ed], args.hist_length, args.pred_length)
val_dataset = GraphDataset(node_feature[:, valid_st:valid_ed], args.hist_length, args.pred_length)
test_dataset = GraphDataset(node_feature[:, test_st:test_ed], args.hist_length, args.pred_length)

# %%
train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=args.batch_size, shuffle=False)

# %%
len(train_dataset)
# Out:
# 24508

# %%
train_dataset[24510][0].shape
# Out:
# torch.Size([262, 24])

# %% [markdown]
# ## Model

# %%
class GCN(torch.nn.Module):
    def __init__(self, args):
        super().__init__()
        self.conv1 = GCNConv(args.num_node_features, args.gcn_hidden_dim)
        self.conv2 = GCNConv(args.gcn_hidden_dim, args.gcn_hidden_dim)

    def forward(self, node_feature, edge_index):
        x = self.conv1(node_feature, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# %%
class GRU_Encoder(torch.nn.Module):
    def __init__(self, args):
        super().__init__()
        self.feature_extractor = GCN(args)
        self.gru1 = nn.GRU(input_size=args.gcn_hidden_dim, hidden_size=args.encoder_hidden_dim)
        self.gru2 = nn.GRU(input_size=args.encoder_hidden_dim, hidden_size=args.encoder_hidden_dim)
        
    def forward(self, batchx, edge_index):
        GCN_output = []
        for i in range(batchx[0].shape[1]):
            gcn_feature = self.feature_extractor(torch.unsqueeze(batchx[0][:, i], 1), edge_index)
            GCN_output.append(gcn_feature)
        
        out = torch.stack(GCN_output)
        out, h1 = self.gru1(out)
        out, h2 = self.gru2(out)
        return h1, h2

# %%
class GRU_Decoder(torch.nn.Module):
    def __init__(self, args):
        super().__init__()
        self.gcn = GCN(args)
        self.gru1 = nn.GRUCell(input_size=args.gcn_hidden_dim, hidden_size=args.decoder_hidden_dim)
        self.gru2 = nn.GRUCell(input_size=args.decoder_hidden_dim, hidden_size=args.decoder_hidden_dim)
        self.pred = nn.Linear(args.decoder_hidden_dim, args.zone_num)
    
    def forward(self, input_graph, edge_index, h1, h2):
        graph_embed = self.gcn(input_graph, edge_index)
        h1 = self.gru1(graph_embed, h1)
        h2 = self.gru2(torch.squeeze(h1), h2)
        out_graph = self.pred(torch.squeeze(h2))
        return (out_graph, h1, h2)

# %%
class Graph_Seq2Seq(torch.nn.Module):
    def __init__(self, args, initial_feature):
        super().__init__()
        self.initial_feature = initial_feature
        self.encoder = GRU_Encoder(args)
        self.decoder = GRU_Decoder(args)
        
    def forward(self, input_seq, edge_index, pred_len):
        graph_li = []
        h1, h2 = self.encoder(input_seq, edge_index)
        graph = self.initial_feature
        for i in range(pred_len):
            out_graph, h1, h2 = self.decoder(graph, edge_index, torch.squeeze(h1), torch.squeeze(h2))
            graph_li.append(out_graph)
        pred = torch.stack(graph_li)
        return pred

# %%
#initial_feature = torch.unsqueeze(node_feature.mean(1), 1)
#model = Graph_Seq2Seq(args, initial_feature)
#for (batchx, batchy) in train_loader:
#    x = model(batchx, edge_index, 12)
#    print(x)
#    i += 1

# %%
args.device
# Out:
# device(type='cpu')

# %%
def train(model, criterion, optimizer, edge_index, args):
    model.train()
    eval_loss = []
    edge_index = edge_index.to(args.device)
    for batchIdx, (batchx, batchy) in enumerate(train_loader):
        optimizer.zero_grad()
        batchx = batchx.to(args.device)
        batchy = batchy.to(args.device)
        predictions = model(batchx, edge_index, args.pred_length)
        loss = criterion(predictions, batchy.permute(2, 1, 0))
        loss.backward()
        # torch.nn.utils.clip_grad_norm_(model.parameters(), 2)
        optimizer.step()
        eval_loss.append(loss.detach().numpy())
        end = time.time()
        print('train loss:', loss)
    return np.mean(eval_loss)

# %%
def valid(model, criterion, edge_index, args):
    model.eval()
    eval_loss = []
    edge_index = edge_index.to(args.device)
    for batchIdx, (batchx, batchy) in enumerate(train_loader):
        optimizer.zero_grad()
        batchx = batchx.to(args.device)
        batchy = batchy.to(args.device)
        predictions = model(batchx, edge_index, args.pred_length)
        loss = criterion(predictions, batchy.permute(2, 1, 0))
        eval_loss.append(loss.detach().numpy())
        end = time.time()
    return np.mean(eval_loss)

# %%
model = Graph_Seq2Seq(args, initial_feature).to(args.device)
criterion = F.mse_loss
optimizer = optim.Adam(model.parameters(), amsgrad=True)

for i in range(args.epoch_num):
    train_loss = train(model, criterion, optimizer, edge_index, args)
    print('----------------------------- epoch {} train loss {} ------------------------------'.format(i, train_loss))
    eval_loss = valid(model, criterion, edge_index, args)
    print('----------------------------- epoch {} eval loss {} ------------------------------'.format(i, eval_loss))
# Out:
# train loss: tensor(13674.5430, grad_fn=<MseLossBackward0>)
# train loss: tensor(13369.1904, grad_fn=<MseLossBackward0>)
# train loss: tensor(15390.6553, grad_fn=<MseLossBackward0>)
# train loss: tensor(24052.2910, grad_fn=<MseLossBackward0>)
# train loss: tensor(18861.7793, grad_fn=<MseLossBackward0>)
# train loss: tensor(4009.0461, grad_fn=<MseLossBackward0>)
# train loss: tensor(8033.1475, grad_fn=<MseLossBackward0>)
# train loss: tensor(29382.9355, grad_fn=<MseLossBackward0>)
# train loss: tensor(9519.3779, grad_fn=<MseLossBackward0>)
# train loss: tensor(9859.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(21745.8828, grad_fn=<MseLossBackward0>)
# train loss: tensor(32618.3633, grad_fn=<MseLossBackward0>)
# train loss: tensor(21214.6113, grad_fn=<MseLossBackward0>)
# train loss: tensor(15384.6182, grad_fn=<MseLossBackward0>)
# train loss: tensor(14029.1504, grad_fn=<MseLossBackward0>)
# train loss: tensor(7277.2632, grad_fn=<MseLossBackward0>)
# train loss: tensor(11530.6338, grad_fn=<MseLossBackward0>)
# train loss: tensor(12063.7979, grad_fn=<MseLossBackward0>)
# train loss: tensor(8698.5898, grad_fn=<MseLossBackward0>)
# train loss: tensor(21577.2695, grad_fn=<MseLossBackward0>)
# train loss: tensor(16890.2715, grad_fn=<MseLossBackward0>)
# train loss: tensor(13915.9248, grad_fn=<MseLossBackward0>)
# train loss: tensor(9946.0889, grad_fn=<MseLossBackward0>)
# train loss: tensor(11844.7871, grad_fn=<MseLossBackward0>)
# train loss: tensor(29005.4473, grad_fn=<MseLossBackward0>)
# train loss: tensor(18845.0059, grad_fn=<MseLossBackward0>)
# train loss: tensor(45557.8867, grad_fn=<MseLossBackward0>)
# train loss: tensor(13087.5928, grad_fn=<MseLossBackward0>)
# train loss: tensor(4603.9082, grad_fn=<MseLossBackward0>)
# train loss: tensor(8007.9204, grad_fn=<MseLossBackward0>)
# train loss: tensor(17068.7871, grad_fn=<MseLossBackward0>)
# train loss: tensor(21231.7910, grad_fn=<MseLossBackward0>)
# train loss: tensor(27385.8633, grad_fn=<MseLossBackward0>)
# train loss: tensor(12482.0264, grad_fn=<MseLossBackward0>)
# train loss: tensor(17319.1914, grad_fn=<MseLossBackward0>)
# train loss: tensor(25707.0762, grad_fn=<MseLossBackward0>)
# train loss: tensor(23414.6699, grad_fn=<MseLossBackward0>)
# train loss: tensor(10408.2705, grad_fn=<MseLossBackward0>)
# train loss: tensor(6486.6597, grad_fn=<MseLossBackward0>)
# train loss: tensor(11364.7051, grad_fn=<MseLossBackward0>)
# train loss: tensor(10230.5205, grad_fn=<MseLossBackward0>)
# train loss: tensor(27975.1738, grad_fn=<MseLossBackward0>)
# train loss: tensor(41860.4414, grad_fn=<MseLossBackward0>)
# train loss: tensor(6106.9585, grad_fn=<MseLossBackward0>)
# train loss: tensor(18569.9863, grad_fn=<MseLossBackward0>)
# train loss: tensor(24778.3594, grad_fn=<MseLossBackward0>)
# train loss: tensor(26387.6621, grad_fn=<MseLossBackward0>)
# train loss: tensor(29613.7148, grad_fn=<MseLossBackward0>)
# train loss: tensor(20330.0098, grad_fn=<MseLossBackward0>)
# train loss: tensor(9729.9385, grad_fn=<MseLossBackward0>)
# train loss: tensor(12273.0049, grad_fn=<MseLossBackward0>)
# train loss: tensor(14323.2930, grad_fn=<MseLossBackward0>)
# train loss: tensor(15735.3867, grad_fn=<MseLossBackward0>)
# train loss: tensor(25649.8809, grad_fn=<MseLossBackward0>)
# train loss: tensor(16575.6113, grad_fn=<MseLossBackward0>)
# train loss: tensor(7865.3774, grad_fn=<MseLossBackward0>)
# train loss: tensor(14407.8545, grad_fn=<MseLossBackward0>)
# train loss: tensor(5615.4155, grad_fn=<MseLossBackward0>)
# train loss: tensor(15982.8613, grad_fn=<MseLossBackward0>)
# train loss: tensor(6200.3345, grad_fn=<MseLossBackward0>)
# train loss: tensor(8360.5303, grad_fn=<MseLossBackward0>)
# train loss: tensor(11309.1504, grad_fn=<MseLossBackward0>)
# train loss: tensor(4831.8525, grad_fn=<MseLossBackward0>)
# train loss: tensor(19957.5977, grad_fn=<MseLossBackward0>)
# train loss: tensor(24327.7910, grad_fn=<MseLossBackward0>)
# train loss: tensor(10246.3984, grad_fn=<MseLossBackward0>)
# train loss: tensor(7555.9180, grad_fn=<MseLossBackward0>)
# train loss: tensor(11814.7529, grad_fn=<MseLossBackward0>)
# train loss: tensor(23811.5039, grad_fn=<MseLossBackward0>)
# train loss: tensor(22548.0254, grad_fn=<MseLossBackward0>)
# train loss: tensor(19366.5410, grad_fn=<MseLossBackward0>)
# train loss: tensor(4206.9419, grad_fn=<MseLossBackward0>)
# train loss: tensor(13895.3145, grad_fn=<MseLossBackward0>)
# train loss: tensor(23444.5371, grad_fn=<MseLossBackward0>)
# train loss: tensor(5038.1948, grad_fn=<MseLossBackward0>)
# train loss: tensor(20871.1738, grad_fn=<MseLossBackward0>)
# train loss: tensor(21294.6660, grad_fn=<MseLossBackward0>)
# train loss: tensor(12610.7686, grad_fn=<MseLossBackward0>)
# train loss: tensor(25098.3555, grad_fn=<MseLossBackward0>)
# train loss: tensor(4538.5151, grad_fn=<MseLossBackward0>)
# train loss: tensor(8668.0596, grad_fn=<MseLossBackward0>)
# train loss: tensor(20912.2363, grad_fn=<MseLossBackward0>)
# train loss: tensor(14580.0967, grad_fn=<MseLossBackward0>)
# train loss: tensor(25527.4297, grad_fn=<MseLossBackward0>)
# train loss: tensor(31926.9336, grad_fn=<MseLossBackward0>)
# train loss: tensor(3966.7251, grad_fn=<MseLossBackward0>)
# train loss: tensor(12650.0088, grad_fn=<MseLossBackward0>)
# train loss: tensor(11523.8906, grad_fn=<MseLossBackward0>)
# train loss: tensor(21044.4121, grad_fn=<MseLossBackward0>)
# train loss: tensor(26219.7500, grad_fn=<MseLossBackward0>)
# train loss: tensor(19954.2051, grad_fn=<MseLossBackward0>)
# train loss: tensor(28355.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(12517.9463, grad_fn=<MseLossBackward0>)
# train loss: tensor(29164.5488, grad_fn=<MseLossBackward0>)
# train loss: tensor(14392.6602, grad_fn=<MseLossBackward0>)
# train loss: tensor(9694.8457, grad_fn=<MseLossBackward0>)
# train loss: tensor(31510.6191, grad_fn=<MseLossBackward0>)
# train loss: tensor(20678.5039, grad_fn=<MseLossBackward0>)
# train loss: tensor(11302.7002, grad_fn=<MseLossBackward0>)
# train loss: tensor(27296.8555, grad_fn=<MseLossBackward0>)
# train loss: tensor(28485.1348, grad_fn=<MseLossBackward0>)
# train loss: tensor(4809.1421, grad_fn=<MseLossBackward0>)
# train loss: tensor(22918.5879, grad_fn=<MseLossBackward0>)
# train loss: tensor(8605.3535, grad_fn=<MseLossBackward0>)
# train loss: tensor(7316.5371, grad_fn=<MseLossBackward0>)
# train loss: tensor(27567.2422, grad_fn=<MseLossBackward0>)
# train loss: tensor(9141.0049, grad_fn=<MseLossBackward0>)
# train loss: tensor(13945.4746, grad_fn=<MseLossBackward0>)
# train loss: tensor(39153.1797, grad_fn=<MseLossBackward0>)
# train loss: tensor(19785.8848, grad_fn=<MseLossBackward0>)
# train loss: tensor(7939.7334, grad_fn=<MseLossBackward0>)
# train loss: tensor(12786.0635, grad_fn=<MseLossBackward0>)
# train loss: tensor(21113.1270, grad_fn=<MseLossBackward0>)
# train loss: tensor(9387.3301, grad_fn=<MseLossBackward0>)
# train loss: tensor(26666.6719, grad_fn=<MseLossBackward0>)
# train loss: tensor(34982.0820, grad_fn=<MseLossBackward0>)
# train loss: tensor(12872.8418, grad_fn=<MseLossBackward0>)
# train loss: tensor(16273.7305, grad_fn=<MseLossBackward0>)
# train loss: tensor(22256.3203, grad_fn=<MseLossBackward0>)
# train loss: tensor(14818.1738, grad_fn=<MseLossBackward0>)
# train loss: tensor(23013.3223, grad_fn=<MseLossBackward0>)
# train loss: tensor(8314.5029, grad_fn=<MseLossBackward0>)
# train loss: tensor(10829.0547, grad_fn=<MseLossBackward0>)
# train loss: tensor(6317.7935, grad_fn=<MseLossBackward0>)
# train loss: tensor(12058.7070, grad_fn=<MseLossBackward0>)
# train loss: tensor(4887.3892, grad_fn=<MseLossBackward0>)
# train loss: tensor(15596.2520, grad_fn=<MseLossBackward0>)
# train loss: tensor(15046.9580, grad_fn=<MseLossBackward0>)
# train loss: tensor(12074.1045, grad_fn=<MseLossBackward0>)
# train loss: tensor(34889.7461, grad_fn=<MseLossBackward0>)
# train loss: tensor(17043.9902, grad_fn=<MseLossBackward0>)
# train loss: tensor(72331.3047, grad_fn=<MseLossBackward0>)
# train loss: tensor(15884.8164, grad_fn=<MseLossBackward0>)
# train loss: tensor(10104.4678, grad_fn=<MseLossBackward0>)
# train loss: tensor(22737.7676, grad_fn=<MseLossBackward0>)
# train loss: tensor(16572.5059, grad_fn=<MseLossBackward0>)
# train loss: tensor(12593.1641, grad_fn=<MseLossBackward0>)
# train loss: tensor(15870.3955, grad_fn=<MseLossBackward0>)
# train loss: tensor(30808.1836, grad_fn=<MseLossBackward0>)
# train loss: tensor(22141.3965, grad_fn=<MseLossBackward0>)
# train loss: tensor(11349.5674, grad_fn=<MseLossBackward0>)
# train loss: tensor(15649.9414, grad_fn=<MseLossBackward0>)
# train loss: tensor(9899.0996, grad_fn=<MseLossBackward0>)
# train loss: tensor(11736.7773, grad_fn=<MseLossBackward0>)
# train loss: tensor(21200.2754, grad_fn=<MseLossBackward0>)
# train loss: tensor(6441.0562, grad_fn=<MseLossBackward0>)
# train loss: tensor(13285.6768, grad_fn=<MseLossBackward0>)
# train loss: tensor(12105.6230, grad_fn=<MseLossBackward0>)
# train loss: tensor(30710.2383, grad_fn=<MseLossBackward0>)
# train loss: tensor(14461.2852, grad_fn=<MseLossBackward0>)
# train loss: tensor(18063.6230, grad_fn=<MseLossBackward0>)
# train loss: tensor(26250.0781, grad_fn=<MseLossBackward0>)
# train loss: tensor(7253.3721, grad_fn=<MseLossBackward0>)
# train loss: tensor(11006.0088, grad_fn=<MseLossBackward0>)
# train loss: tensor(7810.1851, grad_fn=<MseLossBackward0>)
# train loss: tensor(9176.2734, grad_fn=<MseLossBackward0>)
# train loss: tensor(14970.5156, grad_fn=<MseLossBackward0>)
# train loss: tensor(26498.7988, grad_fn=<MseLossBackward0>)
# train loss: tensor(6311.3418, grad_fn=<MseLossBackward0>)
# train loss: tensor(11661.9062, grad_fn=<MseLossBackward0>)
# train loss: tensor(21319.7070, grad_fn=<MseLossBackward0>)
# train loss: tensor(15919.3535, grad_fn=<MseLossBackward0>)
# train loss: tensor(12605.2139, grad_fn=<MseLossBackward0>)
# train loss: tensor(20097.1855, grad_fn=<MseLossBackward0>)
# train loss: tensor(16682.2070, grad_fn=<MseLossBackward0>)
# train loss: tensor(32610.1113, grad_fn=<MseLossBackward0>)
# train loss: tensor(7811.0205, grad_fn=<MseLossBackward0>)
# train loss: tensor(23416.0527, grad_fn=<MseLossBackward0>)
# train loss: tensor(18954.1660, grad_fn=<MseLossBackward0>)
# train loss: tensor(12295.3350, grad_fn=<MseLossBackward0>)
# train loss: tensor(22121.7656, grad_fn=<MseLossBackward0>)
# train loss: tensor(2946.4741, grad_fn=<MseLossBackward0>)
# train loss: tensor(9152.8545, grad_fn=<MseLossBackward0>)
# train loss: tensor(14520.8457, grad_fn=<MseLossBackward0>)
# train loss: tensor(6887.5088, grad_fn=<MseLossBackward0>)
# train loss: tensor(11516.5938, grad_fn=<MseLossBackward0>)
# train loss: tensor(11945.9512, grad_fn=<MseLossBackward0>)
# train loss: tensor(28156.0059, grad_fn=<MseLossBackward0>)
# train loss: tensor(20229.7129, grad_fn=<MseLossBackward0>)
# train loss: tensor(17169.5000, grad_fn=<MseLossBackward0>)
# train loss: tensor(8215.2061, grad_fn=<MseLossBackward0>)
# train loss: tensor(5392.6709, grad_fn=<MseLossBackward0>)
# train loss: tensor(25501.4609, grad_fn=<MseLossBackward0>)
# train loss: tensor(22076.5605, grad_fn=<MseLossBackward0>)
# train loss: tensor(6907.8740, grad_fn=<MseLossBackward0>)
# train loss: tensor(8750.6885, grad_fn=<MseLossBackward0>)
# train loss: tensor(11581.6055, grad_fn=<MseLossBackward0>)
# train loss: tensor(9901.9678, grad_fn=<MseLossBackward0>)
# train loss: tensor(11358.0918, grad_fn=<MseLossBackward0>)
# train loss: tensor(13004.2822, grad_fn=<MseLossBackward0>)
# train loss: tensor(9522.7441, grad_fn=<MseLossBackward0>)
# train loss: tensor(13672.1611, grad_fn=<MseLossBackward0>)
# train loss: tensor(11916.8027, grad_fn=<MseLossBackward0>)
# train loss: tensor(10950.5957, grad_fn=<MseLossBackward0>)
# train loss: tensor(6867.5269, grad_fn=<MseLossBackward0>)
# train loss: tensor(10078.0352, grad_fn=<MseLossBackward0>)
# train loss: tensor(15373.6855, grad_fn=<MseLossBackward0>)
# train loss: tensor(16775.3848, grad_fn=<MseLossBackward0>)
# train loss: tensor(22770.1738, grad_fn=<MseLossBackward0>)
# train loss: tensor(19161.6641, grad_fn=<MseLossBackward0>)
# train loss: tensor(12978.2422, grad_fn=<MseLossBackward0>)
# train loss: tensor(20033.4805, grad_fn=<MseLossBackward0>)
# train loss: tensor(20920.6367, grad_fn=<MseLossBackward0>)
# train loss: tensor(12982.3125, grad_fn=<MseLossBackward0>)
# train loss: tensor(21225.8984, grad_fn=<MseLossBackward0>)
# train loss: tensor(25583.2441, grad_fn=<MseLossBackward0>)
# train loss: tensor(7234.1079, grad_fn=<MseLossBackward0>)
# train loss: tensor(15157.4570, grad_fn=<MseLossBackward0>)
# train loss: tensor(11221.8242, grad_fn=<MseLossBackward0>)
# train loss: tensor(9722.9756, grad_fn=<MseLossBackward0>)
# train loss: tensor(12957.6377, grad_fn=<MseLossBackward0>)
# train loss: tensor(20796.7500, grad_fn=<MseLossBackward0>)
# train loss: tensor(21958.5098, grad_fn=<MseLossBackward0>)
# train loss: tensor(21208.8320, grad_fn=<MseLossBackward0>)
# train loss: tensor(35374.9648, grad_fn=<MseLossBackward0>)
# train loss: tensor(11466.5771, grad_fn=<MseLossBackward0>)
# train loss: tensor(23133.8398, grad_fn=<MseLossBackward0>)
# train loss: tensor(15186.2812, grad_fn=<MseLossBackward0>)
# train loss: tensor(18496.3574, grad_fn=<MseLossBackward0>)
# train loss: tensor(12187.7646, grad_fn=<MseLossBackward0>)
# train loss: tensor(8521.2910, grad_fn=<MseLossBackward0>)
# train loss: tensor(15039.2529, grad_fn=<MseLossBackward0>)
# train loss: tensor(22996.0762, grad_fn=<MseLossBackward0>)
# train loss: tensor(13057.5508, grad_fn=<MseLossBackward0>)
# train loss: tensor(10034.4463, grad_fn=<MseLossBackward0>)
# train loss: tensor(30285.1660, grad_fn=<MseLossBackward0>)
# train loss: tensor(10959.9736, grad_fn=<MseLossBackward0>)
# train loss: tensor(2558.1523, grad_fn=<MseLossBackward0>)
# train loss: tensor(12857.6211, grad_fn=<MseLossBackward0>)
# train loss: tensor(11517.3457, grad_fn=<MseLossBackward0>)
# train loss: tensor(4584.6548, grad_fn=<MseLossBackward0>)
# train loss: tensor(82465.5078, grad_fn=<MseLossBackward0>)
# train loss: tensor(29275.3555, grad_fn=<MseLossBackward0>)
# train loss: tensor(22257.7227, grad_fn=<MseLossBackward0>)
# train loss: tensor(2984.9714, grad_fn=<MseLossBackward0>)
# train loss: tensor(7639.4565, grad_fn=<MseLossBackward0>)
# train loss: tensor(5478.3018, grad_fn=<MseLossBackward0>)
# train loss: tensor(19658.5605, grad_fn=<MseLossBackward0>)
# train loss: tensor(8750.8232, grad_fn=<MseLossBackward0>)
# train loss: tensor(13965.7129, grad_fn=<MseLossBackward0>)
# train loss: tensor(27502.5234, grad_fn=<MseLossBackward0>)
# train loss: tensor(18478.6406, grad_fn=<MseLossBackward0>)
# train loss: tensor(6350.1914, grad_fn=<MseLossBackward0>)
# train loss: tensor(29453.7988, grad_fn=<MseLossBackward0>)
# train loss: tensor(28422.7637, grad_fn=<MseLossBackward0>)
# train loss: tensor(22854.1875, grad_fn=<MseLossBackward0>)
# train loss: tensor(6148.9165, grad_fn=<MseLossBackward0>)
# train loss: tensor(10237.6045, grad_fn=<MseLossBackward0>)
# train loss: tensor(7133.4595, grad_fn=<MseLossBackward0>)
# train loss: tensor(8773.3438, grad_fn=<MseLossBackward0>)
# train loss: tensor(9132.9434, grad_fn=<MseLossBackward0>)
# train loss: tensor(4704.9585, grad_fn=<MseLossBackward0>)
# train loss: tensor(8600.3242, grad_fn=<MseLossBackward0>)
# train loss: tensor(53506.5039, grad_fn=<MseLossBackward0>)
# train loss: tensor(27751.8047, grad_fn=<MseLossBackward0>)
# train loss: tensor(23180.9434, grad_fn=<MseLossBackward0>)
# train loss: tensor(13736.5459, grad_fn=<MseLossBackward0>)
# train loss: tensor(11943.2305, grad_fn=<MseLossBackward0>)
# train loss: tensor(16479.1250, grad_fn=<MseLossBackward0>)
# train loss: tensor(7989.0796, grad_fn=<MseLossBackward0>)
# train loss: tensor(19934.7188, grad_fn=<MseLossBackward0>)
# train loss: tensor(24114.5352, grad_fn=<MseLossBackward0>)
# train loss: tensor(5509.1577, grad_fn=<MseLossBackward0>)
# train loss: tensor(9212.1162, grad_fn=<MseLossBackward0>)
# train loss: tensor(17599.6445, grad_fn=<MseLossBackward0>)
# train loss: tensor(10524.7910, grad_fn=<MseLossBackward0>)
# train loss: tensor(33065.4492, grad_fn=<MseLossBackward0>)
# train loss: tensor(32298., grad_fn=<MseLossBackward0>)
# train loss: tensor(14319.4629, grad_fn=<MseLossBackward0>)
# train loss: tensor(12676.3691, grad_fn=<MseLossBackward0>)
# train loss: tensor(10114.6543, grad_fn=<MseLossBackward0>)
# train loss: tensor(22609.6641, grad_fn=<MseLossBackward0>)
# train loss: tensor(16834.5977, grad_fn=<MseLossBackward0>)
# train loss: tensor(5581.3271, grad_fn=<MseLossBackward0>)
# train loss: tensor(18436.5000, grad_fn=<MseLossBackward0>)
# train loss: tensor(16352.2695, grad_fn=<MseLossBackward0>)
# train loss: tensor(25281.0254, grad_fn=<MseLossBackward0>)
# train loss: tensor(15115.7578, grad_fn=<MseLossBackward0>)
# train loss: tensor(8661.0225, grad_fn=<MseLossBackward0>)
# train loss: tensor(14443.0195, grad_fn=<MseLossBackward0>)
# train loss: tensor(7613.6172, grad_fn=<MseLossBackward0>)
# train loss: tensor(10136.6143, grad_fn=<MseLossBackward0>)
# train loss: tensor(12623.7695, grad_fn=<MseLossBackward0>)
# train loss: tensor(13178.4922, grad_fn=<MseLossBackward0>)
# train loss: tensor(13673.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(34211.0898, grad_fn=<MseLossBackward0>)
# train loss: tensor(11794.6348, grad_fn=<MseLossBackward0>)
# train loss: tensor(29963.9805, grad_fn=<MseLossBackward0>)
# train loss: tensor(21524.3262, grad_fn=<MseLossBackward0>)
# train loss: tensor(29249.4141, grad_fn=<MseLossBackward0>)
# train loss: tensor(11504.3691, grad_fn=<MseLossBackward0>)
# train loss: tensor(6943.4517, grad_fn=<MseLossBackward0>)
# train loss: tensor(18603.4297, grad_fn=<MseLossBackward0>)
# train loss: tensor(9534.0693, grad_fn=<MseLossBackward0>)
# train loss: tensor(8240.9805, grad_fn=<MseLossBackward0>)
# train loss: tensor(11216.0127, grad_fn=<MseLossBackward0>)
# train loss: tensor(12501.8877, grad_fn=<MseLossBackward0>)
# train loss: tensor(9532.6484, grad_fn=<MseLossBackward0>)
# train loss: tensor(15643.9629, grad_fn=<MseLossBackward0>)
# train loss: tensor(6585.7754, grad_fn=<MseLossBackward0>)
# train loss: tensor(10927.6807, grad_fn=<MseLossBackward0>)
# train loss: tensor(12747.6016, grad_fn=<MseLossBackward0>)
# train loss: tensor(15222.7197, grad_fn=<MseLossBackward0>)
# train loss: tensor(7788.1392, grad_fn=<MseLossBackward0>)
# train loss: tensor(18012.2324, grad_fn=<MseLossBackward0>)
# train loss: tensor(10305.7979, grad_fn=<MseLossBackward0>)
# train loss: tensor(9849.6074, grad_fn=<MseLossBackward0>)
# train loss: tensor(5228.7632, grad_fn=<MseLossBackward0>)
# train loss: tensor(65269.9727, grad_fn=<MseLossBackward0>)
# train loss: tensor(13211.7871, grad_fn=<MseLossBackward0>)
# train loss: tensor(15722.5645, grad_fn=<MseLossBackward0>)
# train loss: tensor(18929.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(16805.5078, grad_fn=<MseLossBackward0>)
# train loss: tensor(17172.4941, grad_fn=<MseLossBackward0>)
# train loss: tensor(21464.0898, grad_fn=<MseLossBackward0>)
# train loss: tensor(8829.5439, grad_fn=<MseLossBackward0>)
# train loss: tensor(13133.8984, grad_fn=<MseLossBackward0>)
# train loss: tensor(18925.3066, grad_fn=<MseLossBackward0>)
# train loss: tensor(21877.0664, grad_fn=<MseLossBackward0>)
# train loss: tensor(8440.1934, grad_fn=<MseLossBackward0>)
# train loss: tensor(31273.6113, grad_fn=<MseLossBackward0>)
# train loss: tensor(19624.4902, grad_fn=<MseLossBackward0>)
# train loss: tensor(12998.7549, grad_fn=<MseLossBackward0>)
# train loss: tensor(14628.5215, grad_fn=<MseLossBackward0>)
# train loss: tensor(17456.5000, grad_fn=<MseLossBackward0>)
# train loss: tensor(16441.0977, grad_fn=<MseLossBackward0>)
# train loss: tensor(30350.7305, grad_fn=<MseLossBackward0>)
# train loss: tensor(22217.0996, grad_fn=<MseLossBackward0>)
# train loss: tensor(21427.6191, grad_fn=<MseLossBackward0>)
# train loss: tensor(14580.5010, grad_fn=<MseLossBackward0>)
# train loss: tensor(12347.7695, grad_fn=<MseLossBackward0>)
# train loss: tensor(27987.7168, grad_fn=<MseLossBackward0>)
# train loss: tensor(11958.1270, grad_fn=<MseLossBackward0>)
# train loss: tensor(7460.5151, grad_fn=<MseLossBackward0>)
# train loss: tensor(46892.1992, grad_fn=<MseLossBackward0>)
# train loss: tensor(16347.0547, grad_fn=<MseLossBackward0>)
# train loss: tensor(25872.3105, grad_fn=<MseLossBackward0>)
# train loss: tensor(11047.3623, grad_fn=<MseLossBackward0>)
# train loss: tensor(4682.4678, grad_fn=<MseLossBackward0>)
# train loss: tensor(104761.4453, grad_fn=<MseLossBackward0>)
# train loss: tensor(11711.6182, grad_fn=<MseLossBackward0>)
# train loss: tensor(8421.7979, grad_fn=<MseLossBackward0>)
# train loss: tensor(29226.6582, grad_fn=<MseLossBackward0>)
# train loss: tensor(26914.7168, grad_fn=<MseLossBackward0>)
# train loss: tensor(15968.2764, grad_fn=<MseLossBackward0>)
# train loss: tensor(7196.3843, grad_fn=<MseLossBackward0>)
# train loss: tensor(32403.9609, grad_fn=<MseLossBackward0>)
# train loss: tensor(11599.8311, grad_fn=<MseLossBackward0>)
# train loss: tensor(9203.4951, grad_fn=<MseLossBackward0>)
# train loss: tensor(28554.2168, grad_fn=<MseLossBackward0>)
# train loss: tensor(19807.0977, grad_fn=<MseLossBackward0>)
# train loss: tensor(50275.0938, grad_fn=<MseLossBackward0>)
# train loss: tensor(12876.5166, grad_fn=<MseLossBackward0>)
# train loss: tensor(21911.1074, grad_fn=<MseLossBackward0>)
# train loss: tensor(15495.5137, grad_fn=<MseLossBackward0>)
# train loss: tensor(17620.6191, grad_fn=<MseLossBackward0>)
# train loss: tensor(27342.1328, grad_fn=<MseLossBackward0>)
# train loss: tensor(6689.2119, grad_fn=<MseLossBackward0>)
# train loss: tensor(24255.6562, grad_fn=<MseLossBackward0>)
# train loss: tensor(13805.5752, grad_fn=<MseLossBackward0>)
# train loss: tensor(16324.5850, grad_fn=<MseLossBackward0>)
# train loss: tensor(28082.4355, grad_fn=<MseLossBackward0>)
# train loss: tensor(5843.9326, grad_fn=<MseLossBackward0>)
# train loss: tensor(13473.0928, grad_fn=<MseLossBackward0>)
# train loss: tensor(9059.5996, grad_fn=<MseLossBackward0>)
# train loss: tensor(17854.2383, grad_fn=<MseLossBackward0>)
# train loss: tensor(6873.8574, grad_fn=<MseLossBackward0>)
# train loss: tensor(18234.0020, grad_fn=<MseLossBackward0>)
# train loss: tensor(20733.4590, grad_fn=<MseLossBackward0>)
# train loss: tensor(5293.5381, grad_fn=<MseLossBackward0>)
# train loss: tensor(14300.9209, grad_fn=<MseLossBackward0>)
# train loss: tensor(16228.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(8775.5166, grad_fn=<MseLossBackward0>)
# train loss: tensor(16292.6016, grad_fn=<MseLossBackward0>)
# train loss: tensor(13772.0303, grad_fn=<MseLossBackward0>)
# train loss: tensor(8463.4951, grad_fn=<MseLossBackward0>)
# train loss: tensor(13016.5752, grad_fn=<MseLossBackward0>)
# train loss: tensor(15476.7529, grad_fn=<MseLossBackward0>)
# train loss: tensor(18253.1094, grad_fn=<MseLossBackward0>)
# train loss: tensor(22731.1016, grad_fn=<MseLossBackward0>)
# train loss: tensor(24459.0078, grad_fn=<MseLossBackward0>)
# train loss: tensor(7730.6055, grad_fn=<MseLossBackward0>)
# train loss: tensor(33378.9609, grad_fn=<MseLossBackward0>)
# train loss: tensor(15147.7979, grad_fn=<MseLossBackward0>)
# train loss: tensor(7754.2480, grad_fn=<MseLossBackward0>)
# train loss: tensor(30506.9395, grad_fn=<MseLossBackward0>)
# train loss: tensor(21700.0645, grad_fn=<MseLossBackward0>)
# train loss: tensor(6037.6792, grad_fn=<MseLossBackward0>)
# train loss: tensor(10328.9150, grad_fn=<MseLossBackward0>)
# train loss: tensor(22660.9609, grad_fn=<MseLossBackward0>)
# train loss: tensor(22627.6465, grad_fn=<MseLossBackward0>)
# train loss: tensor(23704.3203, grad_fn=<MseLossBackward0>)
# train loss: tensor(33906.5352, grad_fn=<MseLossBackward0>)
# train loss: tensor(6539.6660, grad_fn=<MseLossBackward0>)
# train loss: tensor(25906.4609, grad_fn=<MseLossBackward0>)
# train loss: tensor(86308.4766, grad_fn=<MseLossBackward0>)
# train loss: tensor(8082.3325, grad_fn=<MseLossBackward0>)
# train loss: tensor(10008.8086, grad_fn=<MseLossBackward0>)
# train loss: tensor(6164.3647, grad_fn=<MseLossBackward0>)
# train loss: tensor(17389.1270, grad_fn=<MseLossBackward0>)
# train loss: tensor(27222.5098, grad_fn=<MseLossBackward0>)
# train loss: tensor(7384.6382, grad_fn=<MseLossBackward0>)
# train loss: tensor(23244.5996, grad_fn=<MseLossBackward0>)
# train loss: tensor(7703.6533, grad_fn=<MseLossBackward0>)
# train loss: tensor(8514.4062, grad_fn=<MseLossBackward0>)
# train loss: tensor(16294.8242, grad_fn=<MseLossBackward0>)
# train loss: tensor(12263.2988, grad_fn=<MseLossBackward0>)
# train loss: tensor(23903.7461, grad_fn=<MseLossBackward0>)
# train loss: tensor(8735.8828, grad_fn=<MseLossBackward0>)
# train loss: tensor(12896.1973, grad_fn=<MseLossBackward0>)
# train loss: tensor(16497.2617, grad_fn=<MseLossBackward0>)
# train loss: tensor(21723.2344, grad_fn=<MseLossBackward0>)
# train loss: tensor(27850.2930, grad_fn=<MseLossBackward0>)
# train loss: tensor(10807.3770, grad_fn=<MseLossBackward0>)
# train loss: tensor(9508.9033, grad_fn=<MseLossBackward0>)
# train loss: tensor(19518.0410, grad_fn=<MseLossBackward0>)
# train loss: tensor(24468.4434, grad_fn=<MseLossBackward0>)
# train loss: tensor(27987.1504, grad_fn=<MseLossBackward0>)
# train loss: tensor(11390.2510, grad_fn=<MseLossBackward0>)
# train loss: tensor(24591.8652, grad_fn=<MseLossBackward0>)
# train loss: tensor(14970.4541, grad_fn=<MseLossBackward0>)
# train loss: tensor(20038.7969, grad_fn=<MseLossBackward0>)
# train loss: tensor(19260.3477, grad_fn=<MseLossBackward0>)
# train loss: tensor(9622.4717, grad_fn=<MseLossBackward0>)
# train loss: tensor(27476.7227, grad_fn=<MseLossBackward0>)
# train loss: tensor(9506.5967, grad_fn=<MseLossBackward0>)
# train loss: tensor(10849.9365, grad_fn=<MseLossBackward0>)
# train loss: tensor(14942.6611, grad_fn=<MseLossBackward0>)
# train loss: tensor(9016.5225, grad_fn=<MseLossBackward0>)
# train loss: tensor(18647.5645, grad_fn=<MseLossBackward0>)
# train loss: tensor(10854.4629, grad_fn=<MseLossBackward0>)
# train loss: tensor(17451.7891, grad_fn=<MseLossBackward0>)
# train loss: tensor(9253.2305, grad_fn=<MseLossBackward0>)
# train loss: tensor(10960.0752, grad_fn=<MseLossBackward0>)
# train loss: tensor(25792.0664, grad_fn=<MseLossBackward0>)
# train loss: tensor(39678.6797, grad_fn=<MseLossBackward0>)
# train loss: tensor(7124.7900, grad_fn=<MseLossBackward0>)
# train loss: tensor(10025.5537, grad_fn=<MseLossBackward0>)
# train loss: tensor(20159.6602, grad_fn=<MseLossBackward0>)
# train loss: tensor(5397.3340, grad_fn=<MseLossBackward0>)
# train loss: tensor(14541.6289, grad_fn=<MseLossBackward0>)
# train loss: tensor(16442.8340, grad_fn=<MseLossBackward0>)
# train loss: tensor(22184.4688, grad_fn=<MseLossBackward0>)
# train loss: tensor(2666.5908, grad_fn=<MseLossBackward0>)
# train loss: tensor(5136.5898, grad_fn=<MseLossBackward0>)
# train loss: tensor(10897.4189, grad_fn=<MseLossBackward0>)
# train loss: tensor(17399.5527, grad_fn=<MseLossBackward0>)
# train loss: tensor(10769.2520, grad_fn=<MseLossBackward0>)
# train loss: tensor(21837.5312, grad_fn=<MseLossBackward0>)
# train loss: tensor(6656.4346, grad_fn=<MseLossBackward0>)
# train loss: tensor(15673.9316, grad_fn=<MseLossBackward0>)
# train loss: tensor(18275.1914, grad_fn=<MseLossBackward0>)
# train loss: tensor(18334.0156, grad_fn=<MseLossBackward0>)
# train loss: tensor(16537.9980, grad_fn=<MseLossBackward0>)
# train loss: tensor(4988.5952, grad_fn=<MseLossBackward0>)
# train loss: tensor(11309.8359, grad_fn=<MseLossBackward0>)
# train loss: tensor(21142.4375, grad_fn=<MseLossBackward0>)
# train loss: tensor(2574.2644, grad_fn=<MseLossBackward0>)
# train loss: tensor(26740.2578, grad_fn=<MseLossBackward0>)
# train loss: tensor(15365.5918, grad_fn=<MseLossBackward0>)
# train loss: tensor(6123.5234, grad_fn=<MseLossBackward0>)
# train loss: tensor(23515.4512, grad_fn=<MseLossBackward0>)
# train loss: tensor(18298.7070, grad_fn=<MseLossBackward0>)
# train loss: tensor(19834.1875, grad_fn=<MseLossBackward0>)
# train loss: tensor(17800.5957, grad_fn=<MseLossBackward0>)
# train loss: tensor(38508.1953, grad_fn=<MseLossBackward0>)
# train loss: tensor(27379.5273, grad_fn=<MseLossBackward0>)
# train loss: tensor(18150.8887, grad_fn=<MseLossBackward0>)
# train loss: tensor(30946.4727, grad_fn=<MseLossBackward0>)
# train loss: tensor(83164.1875, grad_fn=<MseLossBackward0>)
# train loss: tensor(32554.9922, grad_fn=<MseLossBackward0>)
# train loss: tensor(11154.8643, grad_fn=<MseLossBackward0>)
# train loss: tensor(95827.8438, grad_fn=<MseLossBackward0>)
# train loss: tensor(19863.8379, grad_fn=<MseLossBackward0>)
# train loss: tensor(13021.9463, grad_fn=<MseLossBackward0>)
# train loss: tensor(19021.2734, grad_fn=<MseLossBackward0>)
# train loss: tensor(18377.8633, grad_fn=<MseLossBackward0>)
# train loss: tensor(30106.7324, grad_fn=<MseLossBackward0>)
# train loss: tensor(6522.7275, grad_fn=<MseLossBackward0>)
# train loss: tensor(10684.6680, grad_fn=<MseLossBackward0>)
# train loss: tensor(10114.3311, grad_fn=<MseLossBackward0>)
# train loss: tensor(7337.0771, grad_fn=<MseLossBackward0>)
# train loss: tensor(25832.7559, grad_fn=<MseLossBackward0>)
# train loss: tensor(69364.5625, grad_fn=<MseLossBackward0>)
# train loss: tensor(11387.5352, grad_fn=<MseLossBackward0>)
# train loss: tensor(12091.1807, grad_fn=<MseLossBackward0>)
# train loss: tensor(11532.1553, grad_fn=<MseLossBackward0>)
# train loss: tensor(11764.2471, grad_fn=<MseLossBackward0>)
# train loss: tensor(3726.3879, grad_fn=<MseLossBackward0>)
# train loss: tensor(6336.4985, grad_fn=<MseLossBackward0>)
# train loss: tensor(8338.4219, grad_fn=<MseLossBackward0>)
# train loss: tensor(35223.5234, grad_fn=<MseLossBackward0>)
# train loss: tensor(6356.8027, grad_fn=<MseLossBackward0>)
# train loss: tensor(13188.5957, grad_fn=<MseLossBackward0>)
# train loss: tensor(2721.1572, grad_fn=<MseLossBackward0>)
# train loss: tensor(19869.3789, grad_fn=<MseLossBackward0>)
# train loss: tensor(10121.1504, grad_fn=<MseLossBackward0>)
# train loss: tensor(9897.8428, grad_fn=<MseLossBackward0>)
# train loss: tensor(19506.3223, grad_fn=<MseLossBackward0>)
# train loss: tensor(11795.3906, grad_fn=<MseLossBackward0>)
# train loss: tensor(7077.3755, grad_fn=<MseLossBackward0>)
# train loss: tensor(8681.8184, grad_fn=<MseLossBackward0>)
# train loss: tensor(14052.9951, grad_fn=<MseLossBackward0>)
# train loss: tensor(25654.3477, grad_fn=<MseLossBackward0>)
# train loss: tensor(13719.7861, grad_fn=<MseLossBackward0>)
# train loss: tensor(10295.2783, grad_fn=<MseLossBackward0>)
# train loss: tensor(4027.5483, grad_fn=<MseLossBackward0>)
# train loss: tensor(8019.0981, grad_fn=<MseLossBackward0>)
# train loss: tensor(29550.4941, grad_fn=<MseLossBackward0>)
# train loss: tensor(20317.9824, grad_fn=<MseLossBackward0>)
# train loss: tensor(19673.4023, grad_fn=<MseLossBackward0>)
# train loss: tensor(20606.6934, grad_fn=<MseLossBackward0>)
# train loss: tensor(12933.8682, grad_fn=<MseLossBackward0>)
# train loss: tensor(11786.8984, grad_fn=<MseLossBackward0>)
# train loss: tensor(16783.3809, grad_fn=<MseLossBackward0>)
# train loss: tensor(14499.9775, grad_fn=<MseLossBackward0>)
# train loss: tensor(12702.4043, grad_fn=<MseLossBackward0>)
# train loss: tensor(28859.4531, grad_fn=<MseLossBackward0>)
# train loss: tensor(17149.2090, grad_fn=<MseLossBackward0>)
# train loss: tensor(12740.6543, grad_fn=<MseLossBackward0>)
# train loss: tensor(22693.4902, grad_fn=<MseLossBackward0>)
# train loss: tensor(20721.8320, grad_fn=<MseLossBackward0>)
# train loss: tensor(15343.0830, grad_fn=<MseLossBackward0>)
# train loss: tensor(23312.4258, grad_fn=<MseLossBackward0>)
# train loss: tensor(23448.7363, grad_fn=<MseLossBackward0>)
# train loss: tensor(6641.1191, grad_fn=<MseLossBackward0>)
# train loss: tensor(18218.0273, grad_fn=<MseLossBackward0>)
# train loss: tensor(6026.0991, grad_fn=<MseLossBackward0>)
# train loss: tensor(19049.2754, grad_fn=<MseLossBackward0>)
# train loss: tensor(19450.8750, grad_fn=<MseLossBackward0>)
# train loss: tensor(40871.2422, grad_fn=<MseLossBackward0>)
# train loss: tensor(5357.4888, grad_fn=<MseLossBackward0>)
# train loss: tensor(19503.7910, grad_fn=<MseLossBackward0>)
# train loss: tensor(21659.7559, grad_fn=<MseLossBackward0>)
# train loss: tensor(9436.4053, grad_fn=<MseLossBackward0>)
# train loss: tensor(11984.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(8570.7148, grad_fn=<MseLossBackward0>)
# train loss: tensor(12355.7305, grad_fn=<MseLossBackward0>)
# train loss: tensor(26975.5684, grad_fn=<MseLossBackward0>)
# train loss: tensor(14818.1816, grad_fn=<MseLossBackward0>)
# train loss: tensor(4387.0806, grad_fn=<MseLossBackward0>)
# train loss: tensor(14360.9004, grad_fn=<MseLossBackward0>)
# train loss: tensor(13156.5039, grad_fn=<MseLossBackward0>)
# train loss: tensor(8362.8838, grad_fn=<MseLossBackward0>)
# train loss: tensor(13499.9971, grad_fn=<MseLossBackward0>)
# train loss: tensor(7519.0625, grad_fn=<MseLossBackward0>)
# train loss: tensor(16098.5977, grad_fn=<MseLossBackward0>)
# train loss: tensor(33369.1133, grad_fn=<MseLossBackward0>)
# train loss: tensor(23327.6465, grad_fn=<MseLossBackward0>)
# train loss: tensor(16239.9492, grad_fn=<MseLossBackward0>)
# train loss: tensor(25133.8555, grad_fn=<MseLossBackward0>)
# train loss: tensor(15276.8184, grad_fn=<MseLossBackward0>)
# train loss: tensor(14880.7705, grad_fn=<MseLossBackward0>)
# train loss: tensor(6434.3901, grad_fn=<MseLossBackward0>)
# train loss: tensor(24359.9766, grad_fn=<MseLossBackward0>)
# train loss: tensor(22019.2422, grad_fn=<MseLossBackward0>)
# train loss: tensor(12111.4316, grad_fn=<MseLossBackward0>)
# train loss: tensor(15867.9238, grad_fn=<MseLossBackward0>)
# train loss: tensor(6206.4668, grad_fn=<MseLossBackward0>)
# train loss: tensor(19642.0703, grad_fn=<MseLossBackward0>)
# train loss: tensor(14089.5508, grad_fn=<MseLossBackward0>)
# train loss: tensor(4956.9346, grad_fn=<MseLossBackward0>)
# train loss: tensor(19785.9844, grad_fn=<MseLossBackward0>)
# train loss: tensor(20295.9727, grad_fn=<MseLossBackward0>)
# train loss: tensor(11260.7363, grad_fn=<MseLossBackward0>)
# train loss: tensor(4353.3838, grad_fn=<MseLossBackward0>)
# train loss: tensor(26254.3262, grad_fn=<MseLossBackward0>)
# train loss: tensor(29785.0352, grad_fn=<MseLossBackward0>)
# train loss: tensor(11142.2314, grad_fn=<MseLossBackward0>)
# train loss: tensor(19795.4707, grad_fn=<MseLossBackward0>)
# train loss: tensor(8172.7661, grad_fn=<MseLossBackward0>)
# train loss: tensor(8922.6543, grad_fn=<MseLossBackward0>)
# train loss: tensor(7964.5864, grad_fn=<MseLossBackward0>)
# train loss: tensor(7558.7925, grad_fn=<MseLossBackward0>)
# train loss: tensor(12297.1582, grad_fn=<MseLossBackward0>)
# train loss: tensor(24394.9922, grad_fn=<MseLossBackward0>)
# train loss: tensor(22630.2715, grad_fn=<MseLossBackward0>)
# train loss: tensor(19485.2891, grad_fn=<MseLossBackward0>)
# train loss: tensor(14106.6582, grad_fn=<MseLossBackward0>)
# train loss: tensor(12199.7158, grad_fn=<MseLossBackward0>)
# train loss: tensor(8270.9082, grad_fn=<MseLossBackward0>)
# train loss: tensor(26949.6621, grad_fn=<MseLossBackward0>)
# train loss: tensor(5865.6118, grad_fn=<MseLossBackward0>)
# train loss: tensor(9080.8096, grad_fn=<MseLossBackward0>)
# train loss: tensor(13474.4824, grad_fn=<MseLossBackward0>)
# train loss: tensor(21421.3965, grad_fn=<MseLossBackward0>)
# train loss: tensor(16083.1836, grad_fn=<MseLossBackward0>)
# train loss: tensor(9462.1777, grad_fn=<MseLossBackward0>)
# train loss: tensor(7678.5176, grad_fn=<MseLossBackward0>)
# train loss: tensor(5217.7998, grad_fn=<MseLossBackward0>)
# train loss: tensor(16349.7559, grad_fn=<MseLossBackward0>)
# train loss: tensor(9163.4150, grad_fn=<MseLossBackward0>)
# train loss: tensor(25276.6719, grad_fn=<MseLossBackward0>)
# train loss: tensor(5991.6221, grad_fn=<MseLossBackward0>)
# train loss: tensor(24819.6387, grad_fn=<MseLossBackward0>)
# train loss: tensor(8324.4697, grad_fn=<MseLossBackward0>)
# train loss: tensor(25191.2695, grad_fn=<MseLossBackward0>)
# train loss: tensor(25598.4883, grad_fn=<MseLossBackward0>)
# train loss: tensor(11287.1104, grad_fn=<MseLossBackward0>)
# train loss: tensor(22889.6387, grad_fn=<MseLossBackward0>)
# train loss: tensor(20772.4629, grad_fn=<MseLossBackward0>)
# train loss: tensor(11906.9756, grad_fn=<MseLossBackward0>)
# train loss: tensor(2865.6724, grad_fn=<MseLossBackward0>)
# train loss: tensor(8076.3955, grad_fn=<MseLossBackward0>)
# train loss: tensor(23784.5645, grad_fn=<MseLossBackward0>)
# train loss: tensor(18351.6406, grad_fn=<MseLossBackward0>)
# train loss: tensor(14842.6006, grad_fn=<MseLossBackward0>)
# train loss: tensor(8625.1426, grad_fn=<MseLossBackward0>)
# train loss: tensor(9291.9346, grad_fn=<MseLossBackward0>)
# train loss: tensor(9627.5576, grad_fn=<MseLossBackward0>)
# train loss: tensor(7646.6855, grad_fn=<MseLossBackward0>)
# train loss: tensor(2958.4656, grad_fn=<MseLossBackward0>)
# train loss: tensor(5854.5293, grad_fn=<MseLossBackward0>)
# train loss: tensor(17207.1953, grad_fn=<MseLossBackward0>)
# train loss: tensor(19692.1523, grad_fn=<MseLossBackward0>)
# train loss: tensor(28155.3789, grad_fn=<MseLossBackward0>)
# train loss: tensor(88959.4531, grad_fn=<MseLossBackward0>)
# train loss: tensor(27313.2363, grad_fn=<MseLossBackward0>)
# train loss: tensor(27197.4297, grad_fn=<MseLossBackward0>)
# train loss: tensor(23554.1758, grad_fn=<MseLossBackward0>)
# train loss: tensor(25013.3867, grad_fn=<MseLossBackward0>)
# train loss: tensor(14876.1455, grad_fn=<MseLossBackward0>)
# train loss: tensor(6232.4639, grad_fn=<MseLossBackward0>)
# train loss: tensor(12101.2568, grad_fn=<MseLossBackward0>)
# train loss: tensor(4270.1855, grad_fn=<MseLossBackward0>)
# train loss: tensor(4689.2910, grad_fn=<MseLossBackward0>)
# train loss: tensor(10917.6641, grad_fn=<MseLossBackward0>)
# train loss: tensor(11325.7607, grad_fn=<MseLossBackward0>)
# train loss: tensor(6683.5254, grad_fn=<MseLossBackward0>)
# train loss: tensor(6390.1016, grad_fn=<MseLossBackward0>)
# train loss: tensor(5015.6006, grad_fn=<MseLossBackward0>)
# train loss: tensor(6902.1050, grad_fn=<MseLossBackward0>)
# train loss: tensor(34916.5117, grad_fn=<MseLossBackward0>)
# train loss: tensor(11131.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(7004.0649, grad_fn=<MseLossBackward0>)
# train loss: tensor(7041.9575, grad_fn=<MseLossBackward0>)
# train loss: tensor(25169.3340, grad_fn=<MseLossBackward0>)
# train loss: tensor(19107.6035, grad_fn=<MseLossBackward0>)
# train loss: tensor(31125.9473, grad_fn=<MseLossBackward0>)
# train loss: tensor(13597.0352, grad_fn=<MseLossBackward0>)
# train loss: tensor(6173.2793, grad_fn=<MseLossBackward0>)
# train loss: tensor(16778.7598, grad_fn=<MseLossBackward0>)
# train loss: tensor(11756.9971, grad_fn=<MseLossBackward0>)
# train loss: tensor(18933.8379, grad_fn=<MseLossBackward0>)
# train loss: tensor(15486.1064, grad_fn=<MseLossBackward0>)
# train loss: tensor(18922.5020, grad_fn=<MseLossBackward0>)
# train loss: tensor(35786.9805, grad_fn=<MseLossBackward0>)
# train loss: tensor(12056.9961, grad_fn=<MseLossBackward0>)
# train loss: tensor(16408.0312, grad_fn=<MseLossBackward0>)
# train loss: tensor(13809.6816, grad_fn=<MseLossBackward0>)
# train loss: tensor(18159.2031, grad_fn=<MseLossBackward0>)
# train loss: tensor(19774.9512, grad_fn=<MseLossBackward0>)
# train loss: tensor(9117.3564, grad_fn=<MseLossBackward0>)
# train loss: tensor(23680.6777, grad_fn=<MseLossBackward0>)
# train loss: tensor(12390.9570, grad_fn=<MseLossBackward0>)
# train loss: tensor(25346.9590, grad_fn=<MseLossBackward0>)
# train loss: tensor(19500.7168, grad_fn=<MseLossBackward0>)
# train loss: tensor(95988.8281, grad_fn=<MseLossBackward0>)
# train loss: tensor(14616.7734, grad_fn=<MseLossBackward0>)
# train loss: tensor(6756.8096, grad_fn=<MseLossBackward0>)
# train loss: tensor(12264.7949, grad_fn=<MseLossBackward0>)
# train loss: tensor(20322.6445, grad_fn=<MseLossBackward0>)
# train loss: tensor(20894.9473, grad_fn=<MseLossBackward0>)
# train loss: tensor(14551.4902, grad_fn=<MseLossBackward0>)
# train loss: tensor(9082.5312, grad_fn=<MseLossBackward0>)
# train loss: tensor(10405.5752, grad_fn=<MseLossBackward0>)
# train loss: tensor(17026.9512, grad_fn=<MseLossBackward0>)
# train loss: tensor(1216.2532, grad_fn=<MseLossBackward0>)
# train loss: tensor(12865.5000, grad_fn=<MseLossBackward0>)
# train loss: tensor(13217.5791, grad_fn=<MseLossBackward0>)
# train loss: tensor(14634.0918, grad_fn=<MseLossBackward0>)
# train loss: tensor(24849.9688, grad_fn=<MseLossBackward0>)
# train loss: tensor(8354.5723, grad_fn=<MseLossBackward0>)
# train loss: tensor(72232.6562, grad_fn=<MseLossBackward0>)
# train loss: tensor(6032.2339, grad_fn=<MseLossBackward0>)
# train loss: tensor(10593.2100, grad_fn=<MseLossBackward0>)
# train loss: tensor(9654.8906, grad_fn=<MseLossBackward0>)
# train loss: tensor(9443.5771, grad_fn=<MseLossBackward0>)
# train loss: tensor(11871.6289, grad_fn=<MseLossBackward0>)
# train loss: tensor(15037.5508, grad_fn=<MseLossBackward0>)
# train loss: tensor(30393.2871, grad_fn=<MseLossBackward0>)
# train loss: tensor(23369.8262, grad_fn=<MseLossBackward0>)
# train loss: tensor(17326.6797, grad_fn=<MseLossBackward0>)
# train loss: tensor(20269.2070, grad_fn=<MseLossBackward0>)
# train loss: tensor(97231.0625, grad_fn=<MseLossBackward0>)
# train loss: tensor(13698.0352, grad_fn=<MseLossBackward0>)
# train loss: tensor(24475.5547, grad_fn=<MseLossBackward0>)
# train loss: tensor(12529.7598, grad_fn=<MseLossBackward0>)
# train loss: tensor(9335.3516, grad_fn=<MseLossBackward0>)
# train loss: tensor(26893.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(27217.7305, grad_fn=<MseLossBackward0>)
# train loss: tensor(4886.2627, grad_fn=<MseLossBackward0>)
# train loss: tensor(9313.5928, grad_fn=<MseLossBackward0>)
# train loss: tensor(19275.0664, grad_fn=<MseLossBackward0>)
# train loss: tensor(12341.8096, grad_fn=<MseLossBackward0>)
# train loss: tensor(6523.1748, grad_fn=<MseLossBackward0>)
# train loss: tensor(11763.1982, grad_fn=<MseLossBackward0>)
# train loss: tensor(16931.7402, grad_fn=<MseLossBackward0>)
# train loss: tensor(12461.2969, grad_fn=<MseLossBackward0>)
# train loss: tensor(21900.4785, grad_fn=<MseLossBackward0>)
# train loss: tensor(24443.4844, grad_fn=<MseLossBackward0>)
# train loss: tensor(14588.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(29032.4902, grad_fn=<MseLossBackward0>)
# train loss: tensor(14650.3486, grad_fn=<MseLossBackward0>)
# train loss: tensor(17050.7402, grad_fn=<MseLossBackward0>)
# train loss: tensor(10304.0723, grad_fn=<MseLossBackward0>)
# train loss: tensor(11665.7002, grad_fn=<MseLossBackward0>)
# train loss: tensor(8126.3130, grad_fn=<MseLossBackward0>)
# train loss: tensor(18693.3945, grad_fn=<MseLossBackward0>)
# train loss: tensor(10888.1631, grad_fn=<MseLossBackward0>)
# train loss: tensor(15807.3447, grad_fn=<MseLossBackward0>)
# train loss: tensor(17506.6777, grad_fn=<MseLossBackward0>)
# train loss: tensor(14493.0459, grad_fn=<MseLossBackward0>)
# train loss: tensor(21518.7168, grad_fn=<MseLossBackward0>)
# train loss: tensor(24232.5059, grad_fn=<MseLossBackward0>)
# train loss: tensor(8839.7998, grad_fn=<MseLossBackward0>)
# train loss: tensor(29974.5098, grad_fn=<MseLossBackward0>)
# train loss: tensor(23083.6699, grad_fn=<MseLossBackward0>)
# train loss: tensor(16716.2559, grad_fn=<MseLossBackward0>)
# train loss: tensor(2714.8201, grad_fn=<MseLossBackward0>)
# train loss: tensor(12008.1172, grad_fn=<MseLossBackward0>)
# train loss: tensor(16506.1191, grad_fn=<MseLossBackward0>)
# train loss: tensor(14959.1455, grad_fn=<MseLossBackward0>)
# train loss: tensor(15648.6182, grad_fn=<MseLossBackward0>)
# train loss: tensor(28014.9355, grad_fn=<MseLossBackward0>)
# train loss: tensor(11123.8350, grad_fn=<MseLossBackward0>)
# train loss: tensor(7355.6318, grad_fn=<MseLossBackward0>)
# train loss: tensor(23980.3887, grad_fn=<MseLossBackward0>)
# train loss: tensor(22783.7324, grad_fn=<MseLossBackward0>)
# train loss: tensor(17666.4160, grad_fn=<MseLossBackward0>)
# train loss: tensor(14038.1836, grad_fn=<MseLossBackward0>)
# train loss: tensor(8230.7520, grad_fn=<MseLossBackward0>)
# train loss: tensor(30921.2461, grad_fn=<MseLossBackward0>)
# train loss: tensor(26339.6406, grad_fn=<MseLossBackward0>)
# train loss: tensor(23813.9922, grad_fn=<MseLossBackward0>)
# train loss: tensor(6155.6826, grad_fn=<MseLossBackward0>)
# train loss: tensor(16469.4941, grad_fn=<MseLossBackward0>)
# train loss: tensor(13070.5332, grad_fn=<MseLossBackward0>)
# train loss: tensor(21738.9824, grad_fn=<MseLossBackward0>)
# train loss: tensor(10854.3965, grad_fn=<MseLossBackward0>)
# train loss: tensor(10198.2305, grad_fn=<MseLossBackward0>)
# train loss: tensor(33503.2578, grad_fn=<MseLossBackward0>)
# train loss: tensor(7227.3354, grad_fn=<MseLossBackward0>)
# train loss: tensor(65508.9375, grad_fn=<MseLossBackward0>)
# train loss: tensor(11387.5771, grad_fn=<MseLossBackward0>)
# train loss: tensor(14564.6484, grad_fn=<MseLossBackward0>)
# train loss: tensor(14516.8545, grad_fn=<MseLossBackward0>)
# train loss: tensor(17019.3711, grad_fn=<MseLossBackward0>)
# train loss: tensor(32388.7617, grad_fn=<MseLossBackward0>)
# train loss: tensor(17942.7168, grad_fn=<MseLossBackward0>)
# train loss: tensor(7483.7339, grad_fn=<MseLossBackward0>)
# train loss: tensor(9886.8398, grad_fn=<MseLossBackward0>)
# train loss: tensor(5446.0112, grad_fn=<MseLossBackward0>)
# train loss: tensor(21530.8223, grad_fn=<MseLossBackward0>)
# train loss: tensor(21745.2109, grad_fn=<MseLossBackward0>)
# train loss: tensor(11856.2822, grad_fn=<MseLossBackward0>)
# train loss: tensor(12011.0322, grad_fn=<MseLossBackward0>)
# train loss: tensor(12557.2764, grad_fn=<MseLossBackward0>)
# train loss: tensor(122614.8359, grad_fn=<MseLossBackward0>)
# train loss: tensor(18045.9688, grad_fn=<MseLossBackward0>)
# train loss: tensor(18968.6289, grad_fn=<MseLossBackward0>)
# train loss: tensor(12251.2148, grad_fn=<MseLossBackward0>)
# train loss: tensor(23433.0645, grad_fn=<MseLossBackward0>)
# train loss: tensor(90621.0781, grad_fn=<MseLossBackward0>)
# train loss: tensor(24901.3848, grad_fn=<MseLossBackward0>)
# train loss: tensor(25025.0996, grad_fn=<MseLossBackward0>)
# train loss: tensor(19996.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(9571.7451, grad_fn=<MseLossBackward0>)
# train loss: tensor(30632.0410, grad_fn=<MseLossBackward0>)
# train loss: tensor(21307.7109, grad_fn=<MseLossBackward0>)
# train loss: tensor(22330.7500, grad_fn=<MseLossBackward0>)
# train loss: tensor(19784.2031, grad_fn=<MseLossBackward0>)
# train loss: tensor(16679.7383, grad_fn=<MseLossBackward0>)
# train loss: tensor(6169.1289, grad_fn=<MseLossBackward0>)
# train loss: tensor(11503.4512, grad_fn=<MseLossBackward0>)
# train loss: tensor(11721.2871, grad_fn=<MseLossBackward0>)
# train loss: tensor(15132.2070, grad_fn=<MseLossBackward0>)
# train loss: tensor(11044.2607, grad_fn=<MseLossBackward0>)
# train loss: tensor(25620.3594, grad_fn=<MseLossBackward0>)
# train loss: tensor(75339.6172, grad_fn=<MseLossBackward0>)
# train loss: tensor(7207.4658, grad_fn=<MseLossBackward0>)
# train loss: tensor(18763.4434, grad_fn=<MseLossBackward0>)
# train loss: tensor(10675.7021, grad_fn=<MseLossBackward0>)
# train loss: tensor(28596.4453, grad_fn=<MseLossBackward0>)
# train loss: tensor(30948.1016, grad_fn=<MseLossBackward0>)
# train loss: tensor(23303.4863, grad_fn=<MseLossBackward0>)
# train loss: tensor(7759.5059, grad_fn=<MseLossBackward0>)
# train loss: tensor(17908.2344, grad_fn=<MseLossBackward0>)
# train loss: tensor(2216.6680, grad_fn=<MseLossBackward0>)
# train loss: tensor(29232.9062, grad_fn=<MseLossBackward0>)
# train loss: tensor(12679.3809, grad_fn=<MseLossBackward0>)
# train loss: tensor(10997.4316, grad_fn=<MseLossBackward0>)
# train loss: tensor(29161.6328, grad_fn=<MseLossBackward0>)
# train loss: tensor(29298.2285, grad_fn=<MseLossBackward0>)
# train loss: tensor(20208.3320, grad_fn=<MseLossBackward0>)
# train loss: tensor(42701.9180, grad_fn=<MseLossBackward0>)
# train loss: tensor(20229.3262, grad_fn=<MseLossBackward0>)
# train loss: tensor(16895.5605, grad_fn=<MseLossBackward0>)
# train loss: tensor(6050.8481, grad_fn=<MseLossBackward0>)
# train loss: tensor(14208.6455, grad_fn=<MseLossBackward0>)
# train loss: tensor(6898.8804, grad_fn=<MseLossBackward0>)
# train loss: tensor(9430.3848, grad_fn=<MseLossBackward0>)
# train loss: tensor(11272.1777, grad_fn=<MseLossBackward0>)
# train loss: tensor(19630.6973, grad_fn=<MseLossBackward0>)
# train loss: tensor(28536.9160, grad_fn=<MseLossBackward0>)
# train loss: tensor(21539.0527, grad_fn=<MseLossBackward0>)
# train loss: tensor(18721.0586, grad_fn=<MseLossBackward0>)
# train loss: tensor(9189.4326, grad_fn=<MseLossBackward0>)
# train loss: tensor(12651.7197, grad_fn=<MseLossBackward0>)
# train loss: tensor(24646.1992, grad_fn=<MseLossBackward0>)
# train loss: tensor(15389.2031, grad_fn=<MseLossBackward0>)
# train loss: tensor(12833.3691, grad_fn=<MseLossBackward0>)
# train loss: tensor(10130.0342, grad_fn=<MseLossBackward0>)
# train loss: tensor(5126.3647, grad_fn=<MseLossBackward0>)
# train loss: tensor(67292.1250, grad_fn=<MseLossBackward0>)
# train loss: tensor(12355.0039, grad_fn=<MseLossBackward0>)
# train loss: tensor(9146.8389, grad_fn=<MseLossBackward0>)
# ...
# train loss: tensor(10448.6494, grad_fn=<MseLossBackward0>)
# train loss: tensor(8350.3984, grad_fn=<MseLossBackward0>)
# train loss: tensor(11523.0176, grad_fn=<MseLossBackward0>)
# train loss: tensor(4477.9629, grad_fn=<MseLossBackward0>)
# train loss: tensor(8863.4365, grad_fn=<MseLossBackward0>)
# train loss: tensor(2944.2478, grad_fn=<MseLossBackward0>)
# train loss: tensor(2617.8735, grad_fn=<MseLossBackward0>)
# train loss: tensor(1920.9799, grad_fn=<MseLossBackward0>)
# train loss: tensor(7045.3726, grad_fn=<MseLossBackward0>)
# train loss: tensor(8735.2969, grad_fn=<MseLossBackward0>)
# train loss: tensor(3195.6338, grad_fn=<MseLossBackward0>)
# train loss: tensor(5731.3384, grad_fn=<MseLossBackward0>)
# train loss: tensor(3606.0381, grad_fn=<MseLossBackward0>)
# train loss: tensor(5081.4111, grad_fn=<MseLossBackward0>)
# train loss: tensor(9699.4873, grad_fn=<MseLossBackward0>)
# train loss: tensor(3839.6973, grad_fn=<MseLossBackward0>)
# train loss: tensor(4962.7241, grad_fn=<MseLossBackward0>)
# train loss: tensor(3527.1177, grad_fn=<MseLossBackward0>)
# train loss: tensor(10611.0615, grad_fn=<MseLossBackward0>)
# train loss: tensor(8782.0527, grad_fn=<MseLossBackward0>)
# train loss: tensor(9515.5029, grad_fn=<MseLossBackward0>)
# train loss: tensor(5968.9019, grad_fn=<MseLossBackward0>)
# train loss: tensor(6471.1138, grad_fn=<MseLossBackward0>)
# train loss: tensor(4079.5745, grad_fn=<MseLossBackward0>)
# train loss: tensor(3813.7871, grad_fn=<MseLossBackward0>)
# train loss: tensor(4413.0903, grad_fn=<MseLossBackward0>)
# train loss: tensor(5747.3252, grad_fn=<MseLossBackward0>)
# train loss: tensor(6962.7231, grad_fn=<MseLossBackward0>)
# train loss: tensor(6341.3701, grad_fn=<MseLossBackward0>)
# train loss: tensor(7284.6870, grad_fn=<MseLossBackward0>)
# train loss: tensor(8027.4873, grad_fn=<MseLossBackward0>)
# train loss: tensor(6730.9829, grad_fn=<MseLossBackward0>)
# train loss: tensor(45594.9766, grad_fn=<MseLossBackward0>)
# train loss: tensor(13518.3682, grad_fn=<MseLossBackward0>)
# train loss: tensor(2653.4778, grad_fn=<MseLossBackward0>)
# train loss: tensor(6802.2295, grad_fn=<MseLossBackward0>)
# train loss: tensor(6426.8613, grad_fn=<MseLossBackward0>)
# train loss: tensor(2687.0864, grad_fn=<MseLossBackward0>)
# train loss: tensor(8386.4072, grad_fn=<MseLossBackward0>)
# train loss: tensor(4506.9854, grad_fn=<MseLossBackward0>)
# train loss: tensor(7330.7183, grad_fn=<MseLossBackward0>)
# train loss: tensor(12004.6982, grad_fn=<MseLossBackward0>)
# train loss: tensor(4187.2021, grad_fn=<MseLossBackward0>)
# train loss: tensor(4554.5977, grad_fn=<MseLossBackward0>)
# train loss: tensor(2945.0642, grad_fn=<MseLossBackward0>)
# train loss: tensor(2819.8511, grad_fn=<MseLossBackward0>)
# train loss: tensor(8657.0068, grad_fn=<MseLossBackward0>)
# train loss: tensor(4491.2007, grad_fn=<MseLossBackward0>)
# train loss: tensor(6223.7227, grad_fn=<MseLossBackward0>)
# train loss: tensor(1947.7767, grad_fn=<MseLossBackward0>)
# train loss: tensor(3852.2900, grad_fn=<MseLossBackward0>)
# train loss: tensor(12097.9580, grad_fn=<MseLossBackward0>)
# train loss: tensor(4872.2534, grad_fn=<MseLossBackward0>)
# train loss: tensor(5069.4741, grad_fn=<MseLossBackward0>)
# train loss: tensor(12137.4375, grad_fn=<MseLossBackward0>)
# train loss: tensor(8313.8477, grad_fn=<MseLossBackward0>)
# train loss: tensor(2967.6860, grad_fn=<MseLossBackward0>)
# train loss: tensor(8813.9111, grad_fn=<MseLossBackward0>)
# train loss: tensor(3299.2964, grad_fn=<MseLossBackward0>)
# train loss: tensor(6553.4146, grad_fn=<MseLossBackward0>)
# train loss: tensor(7619.4019, grad_fn=<MseLossBackward0>)
# train loss: tensor(7478.1318, grad_fn=<MseLossBackward0>)
# train loss: tensor(1531.4298, grad_fn=<MseLossBackward0>)
# train loss: tensor(10551.9707, grad_fn=<MseLossBackward0>)
# train loss: tensor(12180.5596, grad_fn=<MseLossBackward0>)
# train loss: tensor(6926.2979, grad_fn=<MseLossBackward0>)
# train loss: tensor(5698.7837, grad_fn=<MseLossBackward0>)
# train loss: tensor(5907.0566, grad_fn=<MseLossBackward0>)
# train loss: tensor(3634.1672, grad_fn=<MseLossBackward0>)
# train loss: tensor(7927.0308, grad_fn=<MseLossBackward0>)
# train loss: tensor(9508.3125, grad_fn=<MseLossBackward0>)
# train loss: tensor(4891.1621, grad_fn=<MseLossBackward0>)
# train loss: tensor(5336.9556, grad_fn=<MseLossBackward0>)
# train loss: tensor(7288.9556, grad_fn=<MseLossBackward0>)
# train loss: tensor(2250.6975, grad_fn=<MseLossBackward0>)
# train loss: tensor(7947.0864, grad_fn=<MseLossBackward0>)
# train loss: tensor(9126.1162, grad_fn=<MseLossBackward0>)
# train loss: tensor(1458.6407, grad_fn=<MseLossBackward0>)
# train loss: tensor(9739.7451, grad_fn=<MseLossBackward0>)
# train loss: tensor(13982.1455, grad_fn=<MseLossBackward0>)
# train loss: tensor(5004.2803, grad_fn=<MseLossBackward0>)
# train loss: tensor(13343.3818, grad_fn=<MseLossBackward0>)
# train loss: tensor(7754.1465, grad_fn=<MseLossBackward0>)
# train loss: tensor(4391.3892, grad_fn=<MseLossBackward0>)
# train loss: tensor(13940.2861, grad_fn=<MseLossBackward0>)
# train loss: tensor(7863.4902, grad_fn=<MseLossBackward0>)
# train loss: tensor(6971.2612, grad_fn=<MseLossBackward0>)
# train loss: tensor(5141.8599, grad_fn=<MseLossBackward0>)
# train loss: tensor(14567.1758, grad_fn=<MseLossBackward0>)
# train loss: tensor(3585.6355, grad_fn=<MseLossBackward0>)
# train loss: tensor(4691.2915, grad_fn=<MseLossBackward0>)
# train loss: tensor(5154.3950, grad_fn=<MseLossBackward0>)
# train loss: tensor(4884.5586, grad_fn=<MseLossBackward0>)
# train loss: tensor(6648.2119, grad_fn=<MseLossBackward0>)
# train loss: tensor(6451.2900, grad_fn=<MseLossBackward0>)
# train loss: tensor(9508.1318, grad_fn=<MseLossBackward0>)
# train loss: tensor(1444.2990, grad_fn=<MseLossBackward0>)
# train loss: tensor(2753.1860, grad_fn=<MseLossBackward0>)
# train loss: tensor(9322.0811, grad_fn=<MseLossBackward0>)
# train loss: tensor(3591.8318, grad_fn=<MseLossBackward0>)
# train loss: tensor(7830.9429, grad_fn=<MseLossBackward0>)
# train loss: tensor(10005.5225, grad_fn=<MseLossBackward0>)
# train loss: tensor(2956.3291, grad_fn=<MseLossBackward0>)
# train loss: tensor(1746.2994, grad_fn=<MseLossBackward0>)
# train loss: tensor(5425.5005, grad_fn=<MseLossBackward0>)
# train loss: tensor(5327.1855, grad_fn=<MseLossBackward0>)
# train loss: tensor(12717.5088, grad_fn=<MseLossBackward0>)
# train loss: tensor(4752.3887, grad_fn=<MseLossBackward0>)
# train loss: tensor(9958.4316, grad_fn=<MseLossBackward0>)
# train loss: tensor(59087.9844, grad_fn=<MseLossBackward0>)
# train loss: tensor(1610.3530, grad_fn=<MseLossBackward0>)
# train loss: tensor(9327.4531, grad_fn=<MseLossBackward0>)
# train loss: tensor(5053.2427, grad_fn=<MseLossBackward0>)
# train loss: tensor(2422.7808, grad_fn=<MseLossBackward0>)
# train loss: tensor(5025.2373, grad_fn=<MseLossBackward0>)
# train loss: tensor(6962.0581, grad_fn=<MseLossBackward0>)
# train loss: tensor(3610.1240, grad_fn=<MseLossBackward0>)
# train loss: tensor(3777.7334, grad_fn=<MseLossBackward0>)
# train loss: tensor(7151.4243, grad_fn=<MseLossBackward0>)
# train loss: tensor(9317.1279, grad_fn=<MseLossBackward0>)
# train loss: tensor(6984.5420, grad_fn=<MseLossBackward0>)
# train loss: tensor(3375.4126, grad_fn=<MseLossBackward0>)
# train loss: tensor(5535.3823, grad_fn=<MseLossBackward0>)
# train loss: tensor(3017.1763, grad_fn=<MseLossBackward0>)
# train loss: tensor(7707.7915, grad_fn=<MseLossBackward0>)
# train loss: tensor(5294.5708, grad_fn=<MseLossBackward0>)
# train loss: tensor(1412.1901, grad_fn=<MseLossBackward0>)
# train loss: tensor(4744.4893, grad_fn=<MseLossBackward0>)
# train loss: tensor(4231.7202, grad_fn=<MseLossBackward0>)
# train loss: tensor(4366.1216, grad_fn=<MseLossBackward0>)
# train loss: tensor(3594.9185, grad_fn=<MseLossBackward0>)
# train loss: tensor(6846.2715, grad_fn=<MseLossBackward0>)
# train loss: tensor(6407.6558, grad_fn=<MseLossBackward0>)
# train loss: tensor(6294.0107, grad_fn=<MseLossBackward0>)
# train loss: tensor(6653.7856, grad_fn=<MseLossBackward0>)
# train loss: tensor(9705.9609, grad_fn=<MseLossBackward0>)
# train loss: tensor(8708.6338, grad_fn=<MseLossBackward0>)
# train loss: tensor(5541.0132, grad_fn=<MseLossBackward0>)
# train loss: tensor(58203.7109, grad_fn=<MseLossBackward0>)
# train loss: tensor(5574.0190, grad_fn=<MseLossBackward0>)
# train loss: tensor(8943.1885, grad_fn=<MseLossBackward0>)
# train loss: tensor(4400.1455, grad_fn=<MseLossBackward0>)
# train loss: tensor(6212.2412, grad_fn=<MseLossBackward0>)
# train loss: tensor(10420.6523, grad_fn=<MseLossBackward0>)
# train loss: tensor(6087.5674, grad_fn=<MseLossBackward0>)
# train loss: tensor(4572.3799, grad_fn=<MseLossBackward0>)
# train loss: tensor(8501.0127, grad_fn=<MseLossBackward0>)
# train loss: tensor(41189.8711, grad_fn=<MseLossBackward0>)
# train loss: tensor(30199.9492, grad_fn=<MseLossBackward0>)
# train loss: tensor(6111.7095, grad_fn=<MseLossBackward0>)
# train loss: tensor(3396.8403, grad_fn=<MseLossBackward0>)
# train loss: tensor(16031.1250, grad_fn=<MseLossBackward0>)
# train loss: tensor(3246.7415, grad_fn=<MseLossBackward0>)
# train loss: tensor(12992.6045, grad_fn=<MseLossBackward0>)
# train loss: tensor(4257.6123, grad_fn=<MseLossBackward0>)
# train loss: tensor(3732.6799, grad_fn=<MseLossBackward0>)
# train loss: tensor(2507.2566, grad_fn=<MseLossBackward0>)
# train loss: tensor(6210.4814, grad_fn=<MseLossBackward0>)
# train loss: tensor(3273.6499, grad_fn=<MseLossBackward0>)
# train loss: tensor(7590.2734, grad_fn=<MseLossBackward0>)
# train loss: tensor(4526.3418, grad_fn=<MseLossBackward0>)
# train loss: tensor(8633.1807, grad_fn=<MseLossBackward0>)
# train loss: tensor(5611.3096, grad_fn=<MseLossBackward0>)
# train loss: tensor(4709.4512, grad_fn=<MseLossBackward0>)
# train loss: tensor(5498.8545, grad_fn=<MseLossBackward0>)
# train loss: tensor(6281.4111, grad_fn=<MseLossBackward0>)
# train loss: tensor(87302.0391, grad_fn=<MseLossBackward0>)
# train loss: tensor(6482.1343, grad_fn=<MseLossBackward0>)
# train loss: tensor(3481.8145, grad_fn=<MseLossBackward0>)
# train loss: tensor(6733.2168, grad_fn=<MseLossBackward0>)
# train loss: tensor(5511.4038, grad_fn=<MseLossBackward0>)
# train loss: tensor(14392.2422, grad_fn=<MseLossBackward0>)
# train loss: tensor(4440.6611, grad_fn=<MseLossBackward0>)
# train loss: tensor(7058.2969, grad_fn=<MseLossBackward0>)
# train loss: tensor(1688.1133, grad_fn=<MseLossBackward0>)
# train loss: tensor(4733.5923, grad_fn=<MseLossBackward0>)
# train loss: tensor(9057.3730, grad_fn=<MseLossBackward0>)
# train loss: tensor(3845.9158, grad_fn=<MseLossBackward0>)
# train loss: tensor(1909.0068, grad_fn=<MseLossBackward0>)
# train loss: tensor(9867.3926, grad_fn=<MseLossBackward0>)
# train loss: tensor(7739.6743, grad_fn=<MseLossBackward0>)
# train loss: tensor(1770.8712, grad_fn=<MseLossBackward0>)
# train loss: tensor(8539.3340, grad_fn=<MseLossBackward0>)
# train loss: tensor(5820.9434, grad_fn=<MseLossBackward0>)
# train loss: tensor(5257.6494, grad_fn=<MseLossBackward0>)
# train loss: tensor(7842.9199, grad_fn=<MseLossBackward0>)
# train loss: tensor(3333.8801, grad_fn=<MseLossBackward0>)
# train loss: tensor(3192.9807, grad_fn=<MseLossBackward0>)
# train loss: tensor(5591.8784, grad_fn=<MseLossBackward0>)
# train loss: tensor(5000.0190, grad_fn=<MseLossBackward0>)
# train loss: tensor(7073.4370, grad_fn=<MseLossBackward0>)
# train loss: tensor(9853.5879, grad_fn=<MseLossBackward0>)
# train loss: tensor(5555.2686, grad_fn=<MseLossBackward0>)
# train loss: tensor(6640.1636, grad_fn=<MseLossBackward0>)
# train loss: tensor(6684.7627, grad_fn=<MseLossBackward0>)
# train loss: tensor(5578.6328, grad_fn=<MseLossBackward0>)
# train loss: tensor(5703.1006, grad_fn=<MseLossBackward0>)
# train loss: tensor(4076.3835, grad_fn=<MseLossBackward0>)
# train loss: tensor(66162.8594, grad_fn=<MseLossBackward0>)
# train loss: tensor(5257.9238, grad_fn=<MseLossBackward0>)
# train loss: tensor(3355.6060, grad_fn=<MseLossBackward0>)
# train loss: tensor(5579.2876, grad_fn=<MseLossBackward0>)
# train loss: tensor(18889.8672, grad_fn=<MseLossBackward0>)
# train loss: tensor(6894.0571, grad_fn=<MseLossBackward0>)
# train loss: tensor(2320.8286, grad_fn=<MseLossBackward0>)
# train loss: tensor(9340.4395, grad_fn=<MseLossBackward0>)
# train loss: tensor(3125.9509, grad_fn=<MseLossBackward0>)
# train loss: tensor(3501.3008, grad_fn=<MseLossBackward0>)
# train loss: tensor(4172.4282, grad_fn=<MseLossBackward0>)
# train loss: tensor(3742.7612, grad_fn=<MseLossBackward0>)
# train loss: tensor(6752.6768, grad_fn=<MseLossBackward0>)
# train loss: tensor(3014.6016, grad_fn=<MseLossBackward0>)
# train loss: tensor(8460.5264, grad_fn=<MseLossBackward0>)
# train loss: tensor(7158.6006, grad_fn=<MseLossBackward0>)
# train loss: tensor(1474.6835, grad_fn=<MseLossBackward0>)
# train loss: tensor(5371.8774, grad_fn=<MseLossBackward0>)
# train loss: tensor(3346.6877, grad_fn=<MseLossBackward0>)
# train loss: tensor(7283.9136, grad_fn=<MseLossBackward0>)
# train loss: tensor(10310.4541, grad_fn=<MseLossBackward0>)
# train loss: tensor(7151.5103, grad_fn=<MseLossBackward0>)
# train loss: tensor(8662.8184, grad_fn=<MseLossBackward0>)
# train loss: tensor(15901.1172, grad_fn=<MseLossBackward0>)
# train loss: tensor(5141.1167, grad_fn=<MseLossBackward0>)
# train loss: tensor(5033.4272, grad_fn=<MseLossBackward0>)
# train loss: tensor(5034.6504, grad_fn=<MseLossBackward0>)
# train loss: tensor(10821.8750, grad_fn=<MseLossBackward0>)
# train loss: tensor(5138.4409, grad_fn=<MseLossBackward0>)
# train loss: tensor(3984.8005, grad_fn=<MseLossBackward0>)
# train loss: tensor(4175.8691, grad_fn=<MseLossBackward0>)
# train loss: tensor(7571.7651, grad_fn=<MseLossBackward0>)
# train loss: tensor(42003.6094, grad_fn=<MseLossBackward0>)
# train loss: tensor(10555.1553, grad_fn=<MseLossBackward0>)
# train loss: tensor(6033.0234, grad_fn=<MseLossBackward0>)
# train loss: tensor(3638.2058, grad_fn=<MseLossBackward0>)
# train loss: tensor(5513.5518, grad_fn=<MseLossBackward0>)
# train loss: tensor(5892.3550, grad_fn=<MseLossBackward0>)
# train loss: tensor(8094.0322, grad_fn=<MseLossBackward0>)
# train loss: tensor(10319.6455, grad_fn=<MseLossBackward0>)
# train loss: tensor(3593.4685, grad_fn=<MseLossBackward0>)
# train loss: tensor(7926.4180, grad_fn=<MseLossBackward0>)
# train loss: tensor(8250.3096, grad_fn=<MseLossBackward0>)
# train loss: tensor(6682.5815, grad_fn=<MseLossBackward0>)
# train loss: tensor(12214.6260, grad_fn=<MseLossBackward0>)
# train loss: tensor(3791.4915, grad_fn=<MseLossBackward0>)
# train loss: tensor(3586.0149, grad_fn=<MseLossBackward0>)
# train loss: tensor(4323.2344, grad_fn=<MseLossBackward0>)
# train loss: tensor(2129.8818, grad_fn=<MseLossBackward0>)
# train loss: tensor(5836.0176, grad_fn=<MseLossBackward0>)
# train loss: tensor(2403.4634, grad_fn=<MseLossBackward0>)
# train loss: tensor(3028.9517, grad_fn=<MseLossBackward0>)
# train loss: tensor(7387.1548, grad_fn=<MseLossBackward0>)
# train loss: tensor(6966.7100, grad_fn=<MseLossBackward0>)
# train loss: tensor(6615.0210, grad_fn=<MseLossBackward0>)
# train loss: tensor(4903.7075, grad_fn=<MseLossBackward0>)
# train loss: tensor(7845.7612, grad_fn=<MseLossBackward0>)
# train loss: tensor(11667.5205, grad_fn=<MseLossBackward0>)
# train loss: tensor(4791.1729, grad_fn=<MseLossBackward0>)
# train loss: tensor(3217.8801, grad_fn=<MseLossBackward0>)
# train loss: tensor(7988.2100, grad_fn=<MseLossBackward0>)
# train loss: tensor(8199.5488, grad_fn=<MseLossBackward0>)
# train loss: tensor(12603.4951, grad_fn=<MseLossBackward0>)
# train loss: tensor(2927.9021, grad_fn=<MseLossBackward0>)
# train loss: tensor(13603.3828, grad_fn=<MseLossBackward0>)
# train loss: tensor(9878.9170, grad_fn=<MseLossBackward0>)
# train loss: tensor(12364.8662, grad_fn=<MseLossBackward0>)
# train loss: tensor(3277.0105, grad_fn=<MseLossBackward0>)
# train loss: tensor(5215.7290, grad_fn=<MseLossBackward0>)
# train loss: tensor(6286.2676, grad_fn=<MseLossBackward0>)
# train loss: tensor(13786.8320, grad_fn=<MseLossBackward0>)
# train loss: tensor(3364.8191, grad_fn=<MseLossBackward0>)
# train loss: tensor(5563.7544, grad_fn=<MseLossBackward0>)
# train loss: tensor(6138.3555, grad_fn=<MseLossBackward0>)
# train loss: tensor(8623.0225, grad_fn=<MseLossBackward0>)
# train loss: tensor(3199.4023, grad_fn=<MseLossBackward0>)
# train loss: tensor(6988.7944, grad_fn=<MseLossBackward0>)
